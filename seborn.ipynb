# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
import plotly .express as ps

# %%
import pandas as pd

# %%
df= pd.read_csv('fist.dataset.csv',index_col=0,encoding='latin')

# %%
df.head(4)
# Out:
#         0  gpa      iq  plament
# unmaed
# 0       0  6.8  .123.0        1
# 1       1  5.9  .160.0        0
# 2       2  5.3  .120.0        0
# 3       3  7.4  .132.0        1

# %%
#sns.set_theme(style='darkgrid')

# %% [markdown]
# # lmplot axes

# %%
sns.lmplot(x = '0' ,y ='plament',data=df,fit_reg=False)
plt.show()

# %% [markdown]
# # Rational:
# # scatter plot
# # line plot

# %%
sns.scatterplot(x='gpa',y='iq',hue='plament',data= df)
# Out:
# <Axes: xlabel='gpa', ylabel='iq'>

# %% [markdown]
# #replot figure

# %%
sns.relplot(x= 'gpa',y= 'iq',kind='scatter',hue='plament',style='unmaed',data=df)

# %% [markdown]
# # lineplot

# %%
sns.lineplot(x='gpa',y='iq',hue="plament",data=df)
# Out:
# <Axes: xlabel='gpa', ylabel='iq'>

# %%
sns.relplot(x='gpa',y='iq',kind='line',hue='plament',style='plament',size='plament',data=df)

# %% [markdown]
# # face plot  -> used only figure

# %%
sns.relplot(x= 'gpa',y= 'iq',kind='scatter',col='plament',data=df)

# %%
sns.relplot(x= 'gpa',y= 'iq',kind='scatter',row='plament',data=df)

# %%
sns.relplot(x= 'gpa',y= 'iq',kind='scatter',col='plament',row='unmaed', data=df)

# %%
sns.relplot(x= 'gpa',y= 'iq',kind='scatter',col='unmaed',col_wrap=4, data=df)

# %% [markdown]
# # distrubution plot:
# # used for uni analysis

# %% [markdown]
# # figure le->displot
# # axes->hisplot->kdeplot->rugplot

# %%
sns.histplot(x='gpa',data=df)
# Out:
# <Axes: xlabel='gpa', ylabel='Count'>

# %%
sns.displot(x='gpa',kind='hist', bins= 10,data=df)

# %%
sns.displot(x='gpa',kind='hist', bins= 10,hue='plament',data=df)

# %%
sns.displot(x='gpa',kind='hist', bins= 10,hue='plament',element='step',data=df)

# %%
sns.displot(x='gpa',kind='hist', col="plament",element='step',data=df)

# %% [markdown]
# # kdeplot

# %%
sns.kdeplot(x='gpa',hue='plament',fill=True,data=df)
# Out:
# <Axes: xlabel='gpa', ylabel='Density'>

# %%
sns.displot(x='gpa',kind='kde',hue='plament',data=df)

# %% [markdown]
# # rugplot working with other plot

# %%
sns.kdeplot(x='gpa',data=df)
sns.rugplot(x='gpa',data=df)
# Out:
# <Axes: xlabel='gpa', ylabel='Density'>

# %% [markdown]
# # bi histrogram and kdeplot

# %%
sns.histplot(x='gpa',y='iq',data=df)
# Out:
# <Axes: xlabel='gpa', ylabel='iq'>

# %%
sns.kdeplot(x='gpa',y='plament',data=df)
# Out:
# <Axes: xlabel='gpa', ylabel='plament'>

# %% [markdown]
# # heatmap

# %%
data =  pd.read_csv('Stress_Dataset.csv')

# %%
data.head(3)
# Out:
#    Gender  Age  Have you recently experienced stress in your life?  \
# 0       0   20                                                  3
# 1       0   20                                                  2
# 2       0   20                                                  5
#
#    Have you noticed a rapid heartbeat or palpitations?  \
# 0                                                  4
# 1                                                  3
# 2                                                  4
#
#    Have you been dealing with anxiety or tension recently?  \
# 0                                                  2
# 1                                                  2
# 2                                                  2
#
#    Do you face any sleep problems or difficulties falling asleep?  \
# 0                                                  5
# 1                                                  1
# 2                                                  2
#
# ...
